# %% [markdown]
# <a href="https://colab.research.google.com/github/Kwangbin/data_first/blob/main/data_first_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
cd drive/MyDrive/ml/data_first/
# Out:
# /content/drive/MyDrive/ml/data_first

# %%
reserve_tb=pd.read_csv('reserve.csv', encoding='UTF-8')
reserve_tb
# Out:
#      reserve_id hotel_id customer_id  ... checkout_date people_num total_price
# 0            r1     h_75         c_1  ...    2016-03-29          4       97200
# 1            r2    h_219         c_1  ...    2016-07-21          2       20600
# 2            r3    h_179         c_1  ...    2016-10-22          2       33600
# 3            r4    h_214         c_1  ...    2017-03-30          4      194400
# 4            r5     h_16         c_1  ...    2017-09-23          3       68100
# ...         ...      ...         ...  ...           ...        ...         ...
# 4025      r4026    h_129       c_999  ...    2017-07-11          2       16000
# 4026      r4027     h_97       c_999  ...    2017-10-10          2       41800
# 4027      r4028     h_27       c_999  ...    2018-04-04          2       74800
# 4028      r4029     h_48      c_1000  ...    2016-05-13          4      540000
# 4029      r4030    h_117      c_1000  ...    2016-07-09          1       44100
#
# [4030 rows x 9 columns]

# %% [markdown]
# 2. 추출

# %%
#iloc
# 0:6 [0,1,2,3,4,5]

reserve_tb.iloc[:, 0:6]
# Out:
#      reserve_id hotel_id  ... checkin_date checkin_time
# 0            r1     h_75  ...   2016-03-26     10:00:00
# 1            r2    h_219  ...   2016-07-20     11:30:00
# 2            r3    h_179  ...   2016-10-19     09:00:00
# 3            r4    h_214  ...   2017-03-29     11:00:00
# 4            r5     h_16  ...   2017-09-22     10:30:00
# ...         ...      ...  ...          ...          ...
# 4025      r4026    h_129  ...   2017-07-10     09:30:00
# 4026      r4027     h_97  ...   2017-10-09     10:30:00
# 4027      r4028     h_27  ...   2018-04-02     11:30:00
# 4028      r4029     h_48  ...   2016-05-10     09:30:00
# 4029      r4030    h_117  ...   2016-07-06     09:00:00
#
# [4030 rows x 6 columns]

# %%
reserve_tb.iloc[:, 0:4]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime
# 0            r1     h_75         c_1  2016-03-06 13:09:42
# 1            r2    h_219         c_1  2016-07-16 23:39:55
# 2            r3    h_179         c_1  2016-09-24 10:03:17
# 3            r4    h_214         c_1  2017-03-08 03:20:10
# 4            r5     h_16         c_1  2017-09-05 19:50:37
# ...         ...      ...         ...                  ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51
#
# [4030 rows x 4 columns]

# %%
reserve_tb.iloc[0:10, :]
# Out:
#   reserve_id hotel_id customer_id  ... checkout_date people_num total_price
# 0         r1     h_75         c_1  ...    2016-03-29          4       97200
# 1         r2    h_219         c_1  ...    2016-07-21          2       20600
# 2         r3    h_179         c_1  ...    2016-10-22          2       33600
# 3         r4    h_214         c_1  ...    2017-03-30          4      194400
# 4         r5     h_16         c_1  ...    2017-09-23          3       68100
# 5         r6    h_241         c_1  ...    2017-12-06          3       36000
# 6         r7    h_256         c_1  ...    2018-01-28          1      103500
# 7         r8    h_241         c_1  ...    2018-06-09          1        6000
# 8         r9    h_217         c_2  ...    2016-03-27          3       68400
# 9        r10    h_240         c_2  ...    2016-07-17          4      320400
#
# [10 rows x 9 columns]

# %%
#추출시 열이름만 지정해 추출
reserve_tb[['reserve_id','checkin_time']]
# Out:
#      reserve_id checkin_time
# 0            r1     10:00:00
# 1            r2     11:30:00
# 2            r3     09:00:00
# 3            r4     11:00:00
# 4            r5     10:30:00
# ...         ...          ...
# 4025      r4026     09:30:00
# 4026      r4027     10:30:00
# 4027      r4028     11:30:00
# 4028      r4029     09:30:00
# 4029      r4030     09:00:00
#
# [4030 rows x 2 columns]

# %%
reserve_tb.iloc[:,[0,5]]
# Out:
#      reserve_id checkin_time
# 0            r1     10:00:00
# 1            r2     11:30:00
# 2            r3     09:00:00
# 3            r4     11:00:00
# 4            r5     10:30:00
# ...         ...          ...
# 4025      r4026     09:30:00
# 4026      r4027     10:30:00
# 4027      r4028     11:30:00
# 4028      r4029     09:30:00
# 4029      r4030     09:00:00
#
# [4030 rows x 2 columns]

# %%
reserve_tb.loc[:,['reserve_id','checkin_time']]
# Out:
#      reserve_id checkin_time
# 0            r1     10:00:00
# 1            r2     11:30:00
# 2            r3     09:00:00
# 3            r4     11:00:00
# 4            r5     10:30:00
# ...         ...          ...
# 4025      r4026     09:30:00
# 4026      r4027     10:30:00
# 4027      r4028     11:30:00
# 4028      r4029     09:30:00
# 4029      r4030     09:00:00
#
# [4030 rows x 2 columns]

# %%
#drop
#axis = 1  열제거, inplace=True  갱신
reserve_tb.drop(['people_num'],axis=1,inplace=True)

# %%
reserve_tb
# Out:
#      reserve_id hotel_id customer_id  ... checkin_time checkout_date total_price
# 0            r1     h_75         c_1  ...     10:00:00    2016-03-29       97200
# 1            r2    h_219         c_1  ...     11:30:00    2016-07-21       20600
# 2            r3    h_179         c_1  ...     09:00:00    2016-10-22       33600
# 3            r4    h_214         c_1  ...     11:00:00    2017-03-30      194400
# 4            r5     h_16         c_1  ...     10:30:00    2017-09-23       68100
# ...         ...      ...         ...  ...          ...           ...         ...
# 4025      r4026    h_129       c_999  ...     09:30:00    2017-07-11       16000
# 4026      r4027     h_97       c_999  ...     10:30:00    2017-10-10       41800
# 4027      r4028     h_27       c_999  ...     11:30:00    2018-04-04       74800
# 4028      r4029     h_48      c_1000  ...     09:30:00    2016-05-13      540000
# 4029      r4030    h_117      c_1000  ...     09:00:00    2016-07-09       44100
#
# ...
